# %% [markdown]
# ### Implementing Hierarchical Clustering (Agglomerative)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage

# ------------------------
# 1️⃣ Generate dummy data
# ------------------------
X, y_true = make_blobs(n_samples=20, centers=3, cluster_std=0.8, random_state=42)

plt.scatter(X[:,0], X[:,1], c='gray', s=50)
plt.title("Dummy Data for Hierarchical Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# ------------------------
# 2️⃣ Agglomerative Clustering
# ------------------------
n_clusters = 3
hc = AgglomerativeClustering(
    n_clusters=n_clusters,
    metric='euclidean',
    linkage='ward'
)

y_pred = hc.fit_predict(X)
print("Cluster labels:", y_pred)

# ------------------------
# 3️⃣ Silhouette Score
# ------------------------
score = silhouette_score(X, y_pred)
print("Silhouette Score:", score)

# ------------------------
# 4️⃣ Visualize clusters
# ------------------------
plt.scatter(X[:,0], X[:,1], c=y_pred, cmap='viridis', s=50)
plt.title(f"Agglomerative Clustering (Silhouette Score: {score:.2f})")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# ------------------------
# 5️⃣ Optional: Dendrogram
# ------------------------
Z = linkage(X, method='ward')
plt.figure(figsize=(8,4))
dendrogram(Z, labels=np.arange(X.shape[0]))
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Sample Index")
plt.ylabel("Distance")
plt.show()
# Out:
# Cluster labels: [0 0 0 0 2 1 0 2 2 2 1 2 1 0 1 0 1 1 2 2]
# Silhouette Score: 0.8689186203037454

# %% [markdown]
# ### From scratch

# %%
n_samples, n_features = X.shape

# %%
n_clusters = n_samples
d = np.ones((n_samples,np.samples)) * np.inf

#empty dictionary key i value i,j where key is always the minimum

# while n_clusters > 1:
for i in range(n_samples):
        for j in range(i):
            d_ij = np.linalg.norm(X[i,:]-X[j,:])
            if d[i,j]> d_ij:
                d[i,j]=d_ij
                d[j,i]=d_ij
                            
# Keep track of clusters as sets of indices
clusters = {i: [i] for i in range(n_samples)}

# Store the hierarchy
